# %%
import random
import time
from IPython.display import clear_output
from datetime import datetime
startTime = datetime.now()

List1={'Attractive':['Aesthetic','Comely'],'Avodi OR Dodge':['Avert','Circumvent','Deflect','Elude','Evade OR Evasive','Parry','Shirk','Shunt','Skirt','Swerve','Quibble','Head-On(Opposite)','Inevitable(Opposite)','Unavoidable(Opposite)'],'Awkward OR Clumsy':['Fumble','Gauche','Gawky','Ungainly'],'Be Slow OR Waste Of Time':['Dally','Dilatory','Dawdle','Dilly Dally','Laggard','Linger','Malinger'],'Detailed Knowledge OR Intellectual':['Cerebral','Erudite','Pundit'],'Flexible':['Limber','Lithe','Nimble','Supple'],'Foolish Talk':['Babble','Blather','Drawl','Drivel','Gibberish','Jabber','Nonsensical','Prate','Prattle'],'Having Twists OR Turns':['Circuitous','Convoluted','Intertwined','Involved','Meander','Sinuous','Tortuous'],'Horrifying OR Shocking':['Aghast','Appalling','Egregious','Ghastly','Grisly','Gross','Grotesque','Gruesome','Heinous','Hideous','Horrendous','Monstrous','Morbid','Unsightly','Vile'],'Inclination':['Affinity','Aptitude','Bent','Disposed','Penchant','Predilection','Predisposition','Proclivity','Propensity'],'Ineffective':['Futile','Ineffectual','Efficacy(Opposite)','Feckless'],'Optimistic':['Buoyant','Sanguine'],'Prediction':['Augur OR Augury','Forecast','Foresight OR Foresee','Foretell','Presage','Prescience','Prognosis'],'Separate OR Not Connected':['Disjointed','Polarize','Segregated','Nexus(Opposite)'],'Sign(Warning) (-)':['Forebode','Foreshadow','Portend','Portent','Premonition'],'Skillful':['Adept','Adroit','Agile','Consummate','Deft','Dexterous','Proficient','Prowess','Inept(Opposite)','Maladroit(Opposite)'],'Spread':['Diffuse','Disseminate','Promulgate','Propagate'],'Threatening':['Ominous','Sinister','Intimidate'],'To do with teaching':['Pedantic','Didactic','Sophist'],'Very Angry':['Enrage','Fume','Glower','Incense','Infuriate','Irate','Ire','Livid','Rabid','Seethe','Smolder','Wrath'],'Very Talent(Child)':['Prodigy','Precocious']}
List2={'Bitter feelings OR Ill will':['Malevolence','Malice','Rancor','Vicious','Virulent'],'Cautions OR Careful OR Risky(Opposite)':['Chary','Circumspect','Gingerly','Heedful','Leery','Prudent','Wary','Daredevil(Opposite)','Folly(Opposite)','Foolhardy(Opposite)','Rash(Opposite)','Reckless(Opposite)','Caveat'],'Coming Together':['Coalesce','Rally'],'Complain(Low Degree)':['Captious','Carping','Grouse','Querulous'],'Danger':['Jeopardy','Pitfall','Precarious','Snare'],'Disapprove OR Scold':['Assail','Berate','Castigate','Decry','Denounce','Denunciation','Diatribe','Epithet','Excoriate','Fulminate','Invective','Lambaste','Rant','Rile','Revile','Tirade','Upbraid','Vituperative'],'Emphasize':['Accentuate','Foreground','Underscore'],'Hate':['Abhor','Animosity','Antipathy','Aversion','Despicable','Detest','Loathe','Odious','Repel','Repugnant','Repulsion'],'Minor Scolding OR Warning':['Admonish','Censure','Chastise','Chide','Rebuke','Reprimand','Reproach','Reprove'],'Mock OR Disrespect(-)':['Abase','Belittle','Condescend','Contempt','Denigrate','Deride','Disdain','Disparage','Jeer','Lampon','Patronize','Sarcastic','Sardonic','Satire','Scoff','Scorn','Sneer','Snicker','Snide','Spurn','Taunt','Banter(+)','Raillery(+)'],'Old Fashioned OR Outdated':['Antediluvian','Antiquated','Archaic','Dated','Obsolete','Outmode','Quaint'],'Praise':['Acclaim','Accolade','Applaud','Approbation','Commendable','Eulogy','Exalt','Extol','Glorify','Hail','Laud','Lionize','Plaudit','Encomiastic'],'Rebellious OR Unconventional':['Dissident','Heresy','Heretical','Heterodox','Iconoclast','Insurgent','Insurrection','Maverick','Nonconformist','Radical','Reactionary(Opposite)','Renegade','Revolutionary','Subversive','Conservative(Opposite)','Conventional(Opposite)','Orthodox(Opposite)','Hidebound'],'Rule OR Principle':['Axioms','Canons','Dictum','Doctrine','Dogmas','Mandate','Tenets','Ideology'],'Self-Satisfaction(-)':['Gloat','Smirk','Smug','Bask(+)','Complacent'],'Similarity':['Analogy','Antithetical(Opposite)'],'Time Related Words':['Anachronism','Chronicle','Chronological'],'To Defeat OR Surrender':['Drub','Pulverize','Rout','Subjugate','Vanquish','Capitulate'],'Troubled':['Beset','Beleaguered','Plagued']}
List3={'Aggressive OR Argumentative':['Bellicose','Belligerent','Contentious','Disputatious','Fractious','Hostility','Litigious','Polemical','Pugnacious','Truculent'],'Agreement OR Harmony':['Accord','Concord','Conformity','Congruous','Consonance','Discord(Opposite)','Dissonance(Opposite)','Faction(Opposite)','Incompatible(Opposite)','Discrepancy(Opposite)','Irreconcilable(Opposite)'],'Argue OR Fight':['Altercation','Bicker','Brawl','Combat','Contend','Row','Scuffle','Squabble','Tiff','Tussle','Truce(Opposite)'],'Being Alike':['Homogeneity','Uniformity','Heterogeneity(Opposite)'],'Biased':['Bigot','Discriminatory','Prejudiced','Partisan','Disinterested(Opposite)','Tendentious'],'Calm':['Aplomb','Composure','Equanimity','Impassive','Imperturbable','Nonchalant','Phlegmatic','Placid','Serene','Staid','Stolid','Tranquil'],'Confuse':['Astound','Baffle','Befuddle','Bemuse','Bewilder','Confound','Flabbergasted','Foxed','Nonplussed','Obfuscated','Perplex','Stupefy'],'Disturbed OR Agitated':['Consternation','Disconcert','Dismay','Distraught','Faze','Fluster','Frenetic','Hysterical','Implacable','Overwrought','Perturb','Disquiet'],'Dominating(-)':['Absolute','Authoritative','Autocrat','Despot','Dogmatic','Hegemony','Imperious','Martinet','Totalitarian','Tyrant','Doctrinaire'],'Easily noticeable':['Patent','Conspicuous','Prominent'],'Equality':['Commensurate','Parity','Peers','Disparate(Opposite)','Tantamount'],'Excessive Flattery':['Fawn','Fulsome','Obsequious','Sycophant','Adulation'],'Impartial':['Dispassionate','Egalitarian','Equitable','Evenhanded','Objectivity'],'Include Everything':['Comprehensive','Encompass','Expansive','Pervasive'],'Indifferent':['Apathy','Stoic'],'Insulting Words':['Deprecatory','Derogatory','Pejorative'],'Make Hostile':['Alienate','Antagonize','Estrange'],'Narrow Minded OR Regional':['Insular','Myopic','Parochial','Provincial'],'Not Serious OR Disrespect':['Flippant','Frivolous OR Frivolity','Insouciant','Levity','Grave OR Gravity(Opposite)','Blithe','Facetious'],'Overly Obedient(-)':['Grovel','Servile','Slavish','Subservient','Supplicant'],'Present Everywhere':['Omnipresent','Ubiquitous'],'Split OR Gap':['Chasm','Dichotomy','Gulf','Rift','Schism'],'Suppress OR End':['Quash','Quell','Repress','Scotch','Subdue'],'To Come Out From':['Emanate','Emit']}
List4={'Calm Down(+) Make Better':['Allay','Alleviate','Ameliorate','Appease','Assuage','Conciliate','Extenuating','Mitigate','Mollify','Pacify','Placate','Propitiated','Solace','Temper','Exacerbate(Opposite)'],'Crucial OR Significant':['Core','Foremost','Imperative','Indispensable','Mandatory','Momentous','Paramount','Pivotal','Salient','Linchpin'],'Difficult To Understand':['Abstract','Abstruse','Arcane','Esoteric','Mystical','Obscure','Occult','Recondite','Profound(+) OR Profundity','Perspicuous(Opposite)'],'End OR Stop':['Terminate','Culminate','Cease','Onset(Opposite)'],'Enthusiastic OR Excited':['Arbor OR Ardent','Avid','Dynamic','Ebullient','Effervescent','Effusive','Exuberant','Fervent OR Fervor','Frisky','Gushing','Impassioned','Vivacious','Zealous OR Zest','Dampen(Opposite)','Tepid(Opposite)','Rhapsody'],'Happy OR Joyous':['Beam','Ecstasy','Elated','Euphoria','Exhilaration','Exultant','Felicity','Gaiety','Jest','Jocular','Jocund','Jollity','Jovial','Jubilant','Rapturous','Uproarious','Regale'],'Hardworking(+)':['Assiduous','Diligent','Industrious','Painstaking','Sedulous','Toil'],'Irregular OR Periodically':['Fitfully','Intermittent','Occasional','Spasmodic','Sporadic'],'Lacking Energy OR Lazy(-)':['Indolent','Jaded','Lackadaisical','Lackluster','Languid','Lassitude','Lethargic','Listless','Sloth','Sluggish','Torpor OR Torpid'],'Never Ending OR Non-Stop':['Chronic','Incessant','Inexorable','Interminable','Perennial','Relentless'],'Ordinary(-)':['Banat','Cliche','Commonplace','Derivative','Hackney','Humdrum','Mundane','Pedestrian','Platitude','Plebeian','Quotidian','Trite','Unremarkable'],'Related':['Affiliated','Kindred'],'Sad OR Depressed':['Anguish','Bereaved','Bleak','Crestfallen','Dejected','Desolate','Despondent','Forlorn','Glum','Lament','Lugubrious','Melancholy','Plaintive','Woe','Pathos','Poignant'],'Short Lived':['Ephemeral','Evanescent','Fleeting','Transient','Transitory'],'Unimportant OR Trivial':['Expendable','Fringe','Incidental','Inconsequential','Marginalization','Peripheral'],'Unusual OR Exception':['Aberration','Anomaly','Deviate']}
List5={'Cannot be Defeated':['Impervious','Indomitable','Invincible'],'Combine':['Amalgamate','Coalition','Meld','Synthesis'],'Excess':['Abound','Barrage','Bounteous','Copious','Glut','Inundate','Myriad','Plethora','Profuse','Prolific','Steeped','Surfeit','Surge','Teeming'],'Excessive Patriotism (-)':['Chauvinism','Fanatic','Jingoism','Zealot','Idealogue'],'Explain Too Much':['Belabor','Understatement(Opposite)'],'Increase':['Accretion','Aggrandize','Augment','Ballon','Dilate','Enhance','Mounting','Proliferate','Wax'],'Lessen In Intensity':['Abate','Ebb','Recede','Subside'],'Lucky OR Unlucky':['Fortuitous','Opportune','Propitious','Serendipity','Despair(Opposite)','Hapless(Opposite)','Wretched(Opposite)'],'Nervous OR Restless':['Restive','Skittish'],'Pain OR Suffering':['Adversity','Afflictions','Mishap','Ordeals','Trials','Tribulation'],'Poor':['Bankrupt','Destitute','Impecunious','Impoverished','Indigent','Insolvent','Penury','Solvent(Opposite)'],'Reduce OR Restrict':['Constrict','Contract','Curtail','Dwindle','Flag','Wane'],'Relevant':['Apposite','Apropos','Germane','Pertinent'],'Remembering The Past':['Evocative','Hindsight','Nostalgia','Reminiscence','Retrospect','Wistful'],'Routine Behavior':['Obtain','Wont'],'Shortage OR Lack of':['Dearth','Deficit','Paucity','Vacuous'],'Spend Too Much OR Waste(-)':['Prodigal','Profligate','Spendthrift','Squander','Extravagance','Lavish'],'Sure OR Certain OR Conditional(Opposite)':['Absolute','Categorical','Certitude','Conviction','Emphatic','Incontrovertible','Unqualified','Contingent(Opposite)','Provisional(Opposite)','Qualify(Opposite)','Tentative(Opposite)'],'Unclear In Meaning':['Ambivalent','Ambiguous','Equivocal'],'Unwilling To Spend(-)':['Closefisted','Miserly','Niggardly','Parsimonious','Skinflint','Stingy','Stint','Tightfisted','Thrift','Frugal','Husbandry','Economical OR Economy'],'Very High Price(-)':['Exorbitant','Gouging','Prohibitive'],'Very Less(-)':['Exiguous','Meager','Puny','Scanty','Skimpy','Spare','Sparse'],'Wealthy':['Opulent','Affluent']}
List6={'Accept OR Agree OR Given In':['Accede','Acquiesce','Amenable','Assent','Compliant','Comply','Concede','Concur','Pliant','Relent','Succumb','Yield','Docile(Easily Control)','Malleable(Easily Control)'],'Break a Rule':['Breach','Flout','Transgress','Abide(Opposite)','Adhere(Opposite)','Infraction'],'Cancel OR Take Back':['Annul','Disavow','Gainsay','Null','Recant','Renege','Repeal','Repudiate','Rescind','Retract','Revoke','Void'],'Clothing':['Sartorial','Raiment'],'Co-Existing':['Contemporary','Simultaneous'],'Determined(+)':['Dogged','Endure','Immutable','Indefatigable','Persevere','Persistence','Resolute','Steadfast','Tenacious'],'Energizing':['Galvanizing','Invigorating','Revitalizing','Rousing'],'Extra Hence Unnecessary':['Extraneous','Redundant','Superfluous'],'Famous Person':['Eminent','Luminary','Pre-Eminent','Stature'],'Greed':['Avarice','Covetous','Cupidity','Glutton(Food)','Rapacious','Ravenous','Voracious','Mercenary(Materialistic)'],'Overly Noise(-)':['Cacophony','Clamor','Clangor','Din','Discordant','Raucous','Strident','Uproar','Vociferous','Boisterous(Loud and Excited)','Inaudible(Opposite)','Obstreperous'],'Planned OR Spontaneous (Opposite)':['Calculated','Deliberate','Forethought','Intentional','Premeditated','Studied','Extemporaneous(Opposite)','Impetuous(Opposite)','Impromptu(Opposite)','Improvise(Opposite)','Offhand(Opposite)'],'Pleasant Sounding':['Euphony','Melodious','Mellifluous'],'Profitable':['Remunerative','Lucrative'],'Severe':['Acute','Austere'],'Stubborn(-)':['Adamant','Defiant','Incorrigible','Intractable','Intransigent','Obdurate','Obstinate','Pertinacious','Perverse','Recalcitrant','Refractory','Willful'],'Supporter OR Enemy(Opposite)':['Advocate','Ally','Champion','Endorse','Espouse','Lobbyist','Protagonist','Tout','Proponent','Adversary(Opposite)','Antagonist(Opposite)','Detractor(Opposite)','Foe(Opposite)','Impugn(Opposite)','Inimical(Opposite)','Nemesis(Opposite)','Opponent(Opposite)'],'To Approach Something':['Accost(-)','Broach(+)'],'To Make Up OR Create':['Concoct','Devise','Formulate','Conjure'],'To Object OR Resist':['Defy','Demur','Dissent','Take Issue With'],'To Prove False OR To Disprove':['Belie','Debunk','Discredit','Expostulate','Rebut','Refute','Remonstrate'],'Urgent':['Exigent','Pressing']}
List7={'Boring and Repetitious':['Monotonous','Plod','Tedious'],'Clear ( Both Physically and in Meaning)':['Clarity','Elucidate','Exposition','Expound','Limpid','Lucid','Pellucid'],'Correct OR Repair':['Amend','Atone','Disabuse','Expiate','Indemnify','Redemption','Redress','Reparation','Restitution'],'Difficult':['Arduous','Cumbersome','Encumber','Exacting','Onerous','Ponderous','Facile(Opposite)','Laborious'],'Difficulty OR Confusing Situation':['Dilemma','Plight','Predicament','Quandary'],'Disloyalty':['Betray','Perfidy','Fealty(Opposite)','Fidelity(Opposite)'],'Experienced':['Seasoned','Veteran'],'Expert':['Connoisseur','Layperson(Opposite)','Virtuoso'],'Feeling Guilty':['Contrite','Penitent','Remorse','Rueful'],'Happening Before Main Event':['Antecedent','Forerunner','Harbinger','Precedent','Precursor','Antedate'],'Harmful OR Curse':['Anathema','Baleful','Bane','Blight','Deleterious','Detrimental','Malediction','Malignant','Pernicious','Insidious'],'Idealistic':['Quixotic','Utopian'],'Immoral':['Debauchery','Decadent','Degenerate','Depravity','Dissolute','Improbity','Wayward'],'Interval OR Pause':['Abeyance','Hiatus','Lull','Moratorium','Respite'],'Just Beginning OR Developing':['Embryonic','Fledgling','Inchoate','Incipient','Nascent','Rudimentary'],'Lose Strength OR Weaken':['Atrophy','Attenuate','Attrition','Debilitate','Degenerate','Degradation','Effete','Enervate','Enfeeble','Flagging','Sup','Wilt','Wither'],'Restrain OR Set Free (Opposite)':['Bridle','Circumscribe','Constraint','Fetter','Rein','Secure','Shackle','Extricate(Opposite)','Manacle','Emancipate(Opposite)'],'Right To Vote':['Enfranchise','Suffrage'],'Strange':['Eccentric','Foible','Idiosyncrasy','Quirkiness'],'Summary':['Crux','Gist','Precis','Purport','Synopsis'],'Thriving OR Restored':['Burgeon','Regenerate','Rejuvenate','Resuscitation','Revive'],'Unclear OR Hazy':['Amorphous','Becloud','Cloud','Indistinct','Murky','Nebulous'],'Without Mistakes OR Perfect':['Flawless','Immaculate','Impeccable','Infallible','Integrity','Irreproachable','Probity','Rectitude','Unimpeachable']}
List8={'Acting Properly OR Misbehave(opposite)':['Decorous','Demure','Prim','Propriety','Seemly','Execrable(Opposite)','Flagrant(Opposite)','Malfeasance(Opposite)', 'Unbecoming(Opposite)'], 'Chaos OR Confusion':['Bedlam','Pandemonium','Tumultuous','Turbulence','Turmoil','Upheaval','Welter'],'Cheat OR deceive':['Artful','Artifice','Bilk','Chicanery','Crafty','Duplicity','Fleece','Guile','Gulled','Hoodwink','Mislead','Swindle','Wily'],'Criminals OR Law Breakers':['Felon','Menace','Miscreant','Rogue','Scoundrel'],'Disaster':['Calamitous','Cataclysm','Catastrophe','Debacle','Coup(Opposite)'],'Disregard': ['Discount', 'Brush Aside'], 'Doubtful': ['Apprehensive', 'Cynical', 'Dubious', 'Questionable', 'Skeptical'], 'Generous Supporter': ['Altruist', 'Benefactor', 'Beneficent', 'Benevolent', 'Humane','Magnanimous','Munificent','Patron', 'Philanthropist'],'Lack Of Respect': ['Audacious', 'Brazen', 'Cheeky', 'Effrontery', 'Gall', 'Impertinent', 'Impudent', 'Insolent', 'Nerve', 'Presumptuous', 'Temerity'],'Overly Proud': ['Arrogant', 'Bombastic', 'Braggart', 'Bravado', 'Conceited', 'Egotistical', 'Haughty', 'Hubris', 'Pompous', 'Supercilious', 'Swagger', 'Vainglorious', 'Unassuming(Opposite)', 'Elitist'],'Practically OR Possible':['Conceivable', 'Credible', 'Feasible', 'Plausible', 'Pragmatic', 'Utilitarian', 'Verisimilar', 'Viable'],'Pretense Of Morality(-)':['Cant', 'Hypocritical', 'Prig', 'Prude', 'Sanctimonious'],'Repeat': ['Recapitulate', 'Rehash', 'Reiterate'],'Self Control': ['Abstemious', 'Abstinence', 'Celibacy', 'Forbear', 'Moderate', 'Refrain', 'Temperate'],'Shining': ['Effulgent', 'Luminous', 'Lustrous', 'Scintillating'],'Show-off(-)': ['Flamboyance', 'Flaunt', 'Grandiloquent', 'Grandiose', 'Ostentatious', 'Pretentious', 'Panache(+)'],'Speak Less OR Few Words': ['Abbreviated', 'Abridge', 'Brevity', 'Condense', 'Laconic', 'Monosyllabic', 'Pithy','Reticent', 'Succinct','Taciturn'],'Talkative OR Lots Of Words':['Garrulous','Loquacious','Prolix','Verbiage','Verbose','Voluble','Long-winded'],'To Give Control OR Responsibility':['Delegate','Devolve'],'Without Deception':['Dupe','Artless','Credence OR Credible','Credulous','Guileless','Gullible','Naive Or Naivete','Ingenuous']}
List9={'About To Happen': ['Imminent', 'Impending(-)'], 'Careless': ['Lax', 'Negligent', 'Remiss', 'Slipshod', 'Stringent(opposite)'], 'Confirm Or Declare': ['Affirm', 'Ascertain', 'Assert', 'Aver', 'Avow', 'Contend', 'Proclaim', 'Testimony'], 'Easily Affected(-)': ['Prone', 'Subject To', 'Susceptible', 'Vulnerable', 'Impervious(opposite)'], 'Enter Without Permission': ['Encroach', 'Impinge', 'Infringe', 'Intrude', 'Obtrude'], 'Examine Carefully': ['Peruse', 'Pore Over', 'Scrutinize', 'Browse(neutral)'], 'Friendly': ['Affable', 'Amiable', 'Amicable', 'Camaraderie', 'Complaisance', 'Congenial', 'Convivial', 'Cordial', 'Fraternize', 'Genial', 'Gregarious', 'Aloof(opposite)', 'Frigid(opposite)', 'Glacial(opposite)'], 'Give Up': ['Abdicate', 'Abjure', 'Abnegate', 'Cede', 'Forgo', 'Forsake', 'Forswear', 'Relinquish', 'Renounce'], 'Hide Or Cover Or Disguise': ['Camouflage', 'Cloak', 'Dissemble', 'Feign', 'Guise', 'Incognito', 'Mask', 'Masquerade', 'Shroud', 'Veneer'], 'Imitate Or Comic Imitation(neutral)': ['Emulate', 'Simulate', 'Mimic(neutral)', 'Pastiche'], 'Inspiring Fear Or Respect': ['Awe', 'Formidable', 'Redoubtable'], 'Irritable': ['Cantankerous', 'Chagrin', 'Choleric', 'Churlish', 'Curmudgeon', 'Grouchy', 'Gruff', 'Irascible', 'Testiness'], 'Mediator Or Lead(neutral)': ['Arbiter', 'Arbitrator', 'Mediate', 'Officiate(neutral)', 'Preside(neutral)'], 'Offensivel Or Lusty': ['Lascivious', 'Leer', 'Lewd', 'Lurid', 'Obscene', 'Seamy', 'Sordid', 'Vulgar'], 'Respect': ['Commemorate', 'Deference', 'Exalt', 'Hallow', 'Homage', 'Revere', 'Venerate'], 'Secret(-)': ['Clandestine', 'Covert', 'Furtive', 'Oblique', 'Skulk', 'Sly', 'Stealth', 'Surreptitious', 'Overt(opposite)'], 'Take Away Forcibly': ['Appropriate', 'Divest', 'Expropriate', 'Preempt', 'Usurp'], 'To Irritate Or Make Angry': ['Disgruntled', 'Exasperate', 'Grate', 'Harangue', 'Heckle', 'Indignation', 'Infuriate', 'Irksome', 'Miffed', 'Nag', 'Nettle', 'Peeve', 'Pique', 'Vex'], 'To Think Deeply': ['Cogitate', 'Contemplate', 'Deliberate', 'Introspect', 'Mull', 'Muse', 'Pensive', 'Ponder', 'Reflect', 'Ruminate']}
List10={'Accuse Or Defame': ['Aspersion', 'Calumny', 'Defame', 'Libel', 'Malign', 'Obloquy', 'Opprobrium', 'Slander', 'Slur', 'Stigmatization', 'Vilify'], 'Alert': ['Vigilant', 'Disarm(opposite)', 'Inattentive'], 'Attract Or Fascinate': ['Arresting', 'Captivate', 'Delectable', 'Enamored', 'Enthrall', 'Infatuate', 'Mesmerize', 'Rapture', 'Spellbinding', 'Ennui(opposite)'], 'Beginner Or Inexperienced': ['Apprentice', 'Dilettante', 'Novel', 'Novice', 'Rookie'], 'Brave': ['Audacious', 'Chivalry', 'Dauntless', 'Gallant', 'Intrepid', 'Pluck', 'Undaunted', 'Valiant', 'Valor'], 'Contradict Itself': ['Irony Or Ironic', 'Paradox'], 'Counter Attack': ['Retaliate', 'Reprisal'], 'Cure All': ['Panacea', 'Elixir'], 'Delay Or Postpone': ['Adjourn', 'Defer', 'Protract', 'Procrastinate'], 'Disrepute Or Bad Reputation': ['Ignominy', 'Infamy', 'Nefarious', 'Notorious'], 'Embarrass': ['Abash', 'Discomfit', 'Mortify'], 'Fake Or False Or Doubtful': ['Apocryphal', 'Dubious', 'Erroneous', 'Ersatz', 'Fabricate', 'Fallacious', 'Illicit', 'Phony', 'Sham', 'Sophistry', 'Specious', 'Spurious', 'Propaganda'], 'Falsehood': ['Mendacity', 'Perjury', 'Prevarication', 'Veracity(opposite)'], 'Fearful Or Lacking Courage': ['Cower', 'Craven', 'Cringe', 'Daunt', 'Flinch', 'Petrify', 'Pusillanimous', 'Shrink', 'Trepidation'], 'Fluent Or Clear': ['Articulate', 'Coherent', 'Eloquent', 'Enunciate', 'Glib(smooth Talker)', 'Labored(opposite)', 'Ineffable(opposite)'], 'Genuine': ['Authentic', 'Legitimate', 'Veritable', 'Counterfeit(opposite)', 'Factitious(opposite)'], 'Gloomy Or Dark': ['Bleak', 'Somber'], 'Illogical Or Strange': ['Absurd', 'Atypical', 'Bizarre', 'Ludicrous', 'Outlandish', 'Preposterous', 'Uncanny'], 'Immature': ['Callow', 'Puerile'], 'Native Or Local': ['Indigenous', 'Exotic(opposite)'], 'Puzzling': ['Conundrum', 'Cryptic', 'Enigma', 'Garble', 'Inscrutable', 'Intrigue', 'Labyrinth', 'Maze'], 'Rude': ['Boor', 'Brusque', 'Curt', 'Terse'], 'Shy Or Introvert': ['Coy', 'Diffidence', 'Reserved', 'Retiring', 'Timid', 'Timorous'], 'Unintentionally': ['Inadvertently', 'Unwittingly'], 'Widespread(-)': ['Epidemic', 'Pandemic', 'Rampant', 'Endemic(opposite)', 'Rife'], 'Working Under Another': ['Subordinate', 'Underling']}
List11={'Artificial Or Pretense':['Affected', 'Contrived', 'Mannered', 'Posture', 'Pretentious'],'Aware Or Unaware (Opposite)':['Cognizant', 'Oblivious(Opposite)'],'Best Example':['Apotheosis', 'Archetype', 'Embody', 'Epitome', 'Exemplify', 'Paradigm', 'Paragon', 'Personify','Prototype(Neutral)'],'Force Or Put Pressure':['Coercion', 'Compel', 'Compulsion', 'Extort', 'Press', 'Dissuade'],'Get Rid Of Or Cleanse':['Catharsis', 'Expurgate', 'Purge'],'Go Off Track':['Astray', 'Awry', 'Circuitous', 'Desultory', 'Digress', 'Discursive', 'Divergent', 'Ramble', 'Tangential'],'Important Mark':['Hallmark', 'Landmark', 'Milestone', 'Watershed'],'Impure Or Poisonous':['Adulterate', 'Contaminate', 'Noxious', 'Toxic', 'Vitiate'],'Inborn Or Firmly Fixed':['Congenital', 'Entrenched', 'Inherent', 'Innate', 'Intrinsic'],'Intelligent Or Wise':['Acuity', 'Acumen', 'Astute', 'Discerning', 'Discriminating', 'Insightful', 'Judicious', 'Perceptive', 'Perspicacious', 'Prudent', 'Sagacious', 'Sage', 'Savant', 'Impolitic(Opposite)','Shrewd(Neutral)','Canny','Simpleton(Opposite)'],'Not Sacred Or Worldly':['Secular', 'Temporal'],'Persuade Or Flatter':['Cajole', 'Coax', 'Cogent', 'Enjoin', 'Exhort', 'Induce', 'Urge', 'Wheedle','Woo(Neutral)','Blandishment','Court'],'Plead':['Behest', 'Beseech', 'Entreaty', 'Implore', 'Importune', 'Supplicate'],'Prove To Be Right':['Gratuitous(Opposite)', 'Justifiable', 'Necessitate', 'Warrant','Indefensible(Opposite)','Untenable(Opposite)'],'Spoil or Disfigure':['Deface', 'Distort', 'Mar', 'Warp','Impair'],'Spotted Or Stained':['Blemish', 'Debase', 'Sully', 'Taint', 'Tarnish'],'Stupid Or Foolish':['Asinine', 'Fatuous', 'Imbecile', 'Inane', 'Oafish', 'Obtuse'],'Sulking Or Bad Tempered':['Dour', 'Morose', 'Peevish', 'Petulant', 'Pout', 'Saturnine', 'Sullen','Surly'],'Tempt Or Plot Or Trick(-)':['Allure', 'Beguile', 'Collude', 'Connive', 'Conspire', 'Entice', 'Lure', 'Ploy', 'Ruse', 'Scheme', 'Tactic'],'To See':['Behold', 'Discern', 'Espy', 'Perceive', 'Imperceptible(Opposite)'],'Uncover A Secret':['Ferret', 'Unearth', 'Unravel'],'Unmatched Or Unique':['Inimitable', 'Peerless']}
List12={'Desiring Only Pleasure':['Hedonist','Sybarite'],'Dramatic Behavior':['Histrionic','Melodramatic'],'Exclude OR Forbid':['Ostracize','Shun','Taboo'],'Frank':['Candid OR Candor','Forthright','Vocal'],'Fully Satisfied':['Gratify','Quench','Replete','Satiate','Saturate','Suffice'],'Fussy(-)':['Finicky','Nitpicking','Persnickety','Squeamish','Stickler'],'Hint OR Indirect Reference':['Allude OR Allusion','Cue','Implicit','Innuendo','Insinuate','Tacit','Blatant (Opposite)','Explicit (Opposite)','Cite (Opposite)'],'Huge OR Big':['Behemoth','Colossal','Gargantuan','Gigantic','Humongous','Mammoth','Monolithic','Monumental','Prodigious','Titanic','Towering','Voluminous'],'Insignificant':['Marginal','Minute','Negligible','Paltry','Token','Trifle'],'Lacking':['Bereft','Deprived','Devoid','Wanting'],'Long Essay OR Speech':['Discourse','Dissertation','Rhetoric'],'Minor DIfferences':['Nuances','Subtle','Shades'],'Mistake OR Act Done Carelessly':['Botch','Bungle','Misnomer','Tactless','Finesse (Opposite)'],'Pertaining To Religion':['Agnostic','Atheist','Pious','Proselytize','Theist','Theology'],'Place Side By Side':['Abut','Adjacent','Contiguous','Juxtaposition'],'Remove OR Destroy':['Annihilate','Decimate','Efface','Eradicate','Expunge','Exterminate','Extirpate','Obliterate','Perish','Raze','Indelible (Opposite)','Devastate','Excise'],'Small':['Slight','Minuscule','Infinitesimal','Diminutive'],'Strengthen OR Support':['Bastion','Bolster','Buttress','Fortify','Prime','Prop'],'Sympathy':['Compassion','Empathy','Callous (Opposite)'],'Theory Without Evidence':['Hypothetical','Speculate','Empirical (Opposite)'],'Thorough OR Precise':['Conscientious','Fastidious','Meticulous','Nice','Punctilious','Purist','Scrupulous'],'To Do Happily (+)':['Alacrity','Obliging'],'To Do Reluctantly OR Unwillingly (-)':['Balk','Grudging'],'To Guess OR Infer':['Conjecture','Construe','Deduce','Extrapolate','Surmise','Inductive'],'Understand':['Apprehend','Assimilate','Comprehend','Fathom','Intelligible','Illegible (Opposite)'],'Used To':['Habituate','Immune','Inure','Inveterate'],'Weak OR Fragile':['Flimsy','Frail','Intangible','Tenuous','Palpable (Opposite)','Substantial (Opposite)','Tactile (Opposite)','Corporeal'],'Weaken':['Erode','Undercut','Undermine','Subvert','Undergird (Opposite)']}
List13={'Activate OR Speed Up':['Catalyst','Engender','Expedite','Facilitate','Kindle','Precipitate','Prod','Prompt','Propel','Spur','Stimulate'],'Attractive OR Decorative':['Adorn','Embellish','Florid','Garnish','Ornate','Resplendent','Spectacular'],'Ban':['Interdict','Sanction','Veto'],'Blameworthy OR Guilty':['Culpable','Reprehensible'],'Can’t Decide OR Fickle':['Arbitrary','Capricious','Erratic','Inconsistent','Irresolute','Mercurial','Oscillate','Sway','Temperamental','Vacillate','Volatile','Waffle','Waver','Whimsical'],'Careless OR Dirty':['Disheveled','Rumpled','Shabby','Shoddy','Sloppy','Slovenly','Unkempt'],'Confirm OR Support':['Affirm','Clinch','Corroborate','Endorse','Ratify','Substantiate','Testify','Validate','Unfounded (Opposite)'],'Dead End':['Impasse','Stalemate'],'Disrespecting Sacred Things':['Blasphemy','Desecrate','Impious','Profane','Sacrilege','Consecrate (Opposite)','Sacrosanct (Opposite)','Anoint (Opposite)'],'Free From Blame':['Absolve','Acquit','Exculpate','Exonerate','Vindicate'],'Harmless OR Kind':['Benign','Innocuous'],'Helpful':['Officious (-)','Solicitous (+)'],'Left Over':['Remnant','Residual','Trace','Vestige','Modicum (Neutral)'],'Mutual Agreement':['Consensus','Unanimous'],'Not Through OR Superficially':['Cursory','Perfunctory','Summarily'],'Physically Strong':['Robust','Rugged','Sturdy','Vigorous'],'Punish':['Condemn','Convict','Immure','Incarcerate','Sentence','Amnesty (Opposite)','Condone (Opposite)','Reprieve (Opposite)'],'Restrict OR Stop OR Prevent':['Check','Deter','Foil','Forestall','Frustrate','Hinder','Impede OR Impediment','Inhibit','Obstruct','Preclude','Retard','Stymie','Thwart','Occlude','Stanch','Preempt'],'Simple OR Plain OR Boring':['Ascetic','Austere','Bland','Drab','Insipid','Prosaic','Stark','Vapid'],'To Blame OR Accuse OR Charge':['Allege OR Allegation','Implicate','Impute','Incriminate','Indict','Recriminate (Neutral)'],'Unsteady Walk OR Hesitate':['Falter','Flounder','Founder','Fumble','To Run Around','Tottering','Wobbly'],'Without Real Power':['Figurehead','Nominal','Titular']}
List14={'After Effects':['Ramifications','Repercussions','Ensue'],'Bad Smell':['Noisome','Rank'],'Exaggerate':['Hyperbole','Underplay (Opposite)','Understae (Opposite)'],'Excusable':['Venial'],'Farewell':['Valedictory','Parting'],'Harsh OR Biting OR Sharp':['Acerbic','Acrimonious','Caustic','Incisive','Scathing','Trenchant','Euphemism (Opposite)'],'Hesitate On Moral Grounds':['Compunction','Misgivings','Qualms','Scruples','Unscrupulous (Opposite)'],'Inactive':['Dormant','Latent','Quiescent','Stagnant'],'Independence OR Freedom':['Autonomy','Latitude','Sovereign'],'Indirect Experience':['Vicarious'],'Inferior Rank':['Relegate','Demote'],'Reveal OR Hide':['Divulge','Telling','Conceal (Opposite)','Secrete (Opposite)'],'Revenge':['Vengeance','Vindictive','Retribution'],'Seller':['Purveyor','Vendor'],'Spiritual OR Earthy (Opposite)':['Sublime','Base (Opposite)'],'Story':['Anecdote','Narrative'],'To Put On':['Don'],'To Rise Beyond':['Outclass','Transcend'],'To Stir Up OR Revolt':['Goad','Incite','Incendiary','Instigate','Provoke','Sedition','Foment'],'Variety':['Diversity','Eclectic','Motley','Multifaceted','Multifarious','Sundry','Veriegate','Versatile'],'Village Like':['Bucolic','Pastoral','Rustic']}

# listRevise={'List1':List1,'List2':List2,'List3':List3,'List4':List4,'List5':List5,'List6':List6,'List7':List7,'List8':List8,'List9':List9,'List10':List10,'List11':List11,'List12':List12,'List13':List13,'List14':List14}
listRevise={'List1':List1}

listOfList=list(listRevise.keys())

print("Please Enter Number \n1: Serial Revision \n2: Random Revision \n3: Serial Revision With Practise\n4: Random Revision With Practice\n5: List Group Name Revision\n6: Revision Words Only \n7: Random Revision(With Out Time Stamp)\n8: Find Group Using Word")
number=int(input())

if(number==1):
    clear_output()
    for x in range(len(listRevise.keys())):
        randomNumberList=x
        listKey1=list(listRevise[listOfList[randomNumberList]].keys())      
        for x in range(0,len(listRevise[listOfList[randomNumberList]].keys())):
            print("From ",listOfList[randomNumberList],'\n')
            time.sleep(0.5)
            print('Total Words in this group is ',len(listRevise[listOfList[randomNumberList]][listKey1[x]]))
            time.sleep(3)
            print("("+str(listKey1.index(listKey1[x])+1)+") "+str(listKey1[x])+" ("+str(len(listRevise[listOfList[randomNumberList]][listKey1[x]]))+")")
            time.sleep(1)
            for y in range(len(listRevise[listOfList[randomNumberList]][listKey1[x]])):
                time.sleep(2)
                print('  ','('+str(y+1)+')',listRevise[listOfList[randomNumberList]][listKey1[x]][y])
            time.sleep(5)
            clear_output()
            time.sleep(0.5)
    print('Total time to execute this part is ',datetime.now() - startTime)

if(number==2):
    clear_output()
    for x in range(len(listRevise.keys())):
        randomNumberList=random.randint(0,len(listOfList)-1)
        listKey1=list(listRevise[listOfList[randomNumberList]].keys())
        for x in range(len(listRevise[listOfList[randomNumberList]].keys())):
            randomNumber=random.randint(0,len(listKey1)-1)
            time.sleep(0.5)
            print('Do you know this one ?   '+'\t'+'From '+str(listOfList[randomNumberList])+'\n'+'--> '+str(random.choice(listRevise[listOfList[randomNumberList]][listKey1[randomNumber]])))
            time.sleep(1)
            print('\n','Total Words in this group is ',str(len(listRevise[listOfList[randomNumberList]][listKey1[randomNumber]])))
            #time.sleep(len(listRevise[listOfList[randomNumberList]][listKey1[randomNumber]]))
            time.sleep(1)
            print('\n')
            print(str(list(listRevise[listOfList[randomNumberList]].keys()).index(listKey1[randomNumber])+1)+'.' , listKey1[randomNumber],'('+str(len(listRevise[listOfList[randomNumberList]][listKey1[randomNumber]]))+')')
            for y in range(len(listRevise[listOfList[randomNumberList]][listKey1[randomNumber]])):
                time.sleep(2)
                print('  ','('+str(y+1)+')',listRevise[listOfList[randomNumberList]][listKey1[randomNumber]][y])
            time.sleep(2)
            clear_output()
            del listKey1[randomNumber]
        del listOfList[randomNumberList]
    print('Total time to execute this part is ',datetime.now() - startTime)
            
def wordMatch(user,select):
    return (user.upper()==select.upper())           
            
if(number==3):
    clear_output()
    for x in range(len(listRevise.keys())):
        randomNumberList=x
        listKey1=list(listRevise[listOfList[randomNumberList]].keys())
        initial=0
        final=int(len(listRevise[listOfList[randomNumberList]].keys()))
        x=0
        while(x<final):
            correct=0
            incorrect=0
            print("From ",listOfList[randomNumberList])
            print(str(listKey1.index(listKey1[x])+1))
            topic=str(input("Enter Topic Name :  ") )
            print("\t\t"+"("+str(listKey1.index(listKey1[x])+1)+") "+str(listKey1[x])+"  ("+str(len(listRevise[listOfList[randomNumberList]][listKey1[x]]))+")")
            print('\n')
            y=0
            while y<len(listRevise[listOfList[randomNumberList]][listKey1[x]]):
                word=str(input("Enter Name : "))
                if(wordMatch(word,listRevise[listOfList[randomNumberList]][listKey1[x]][y])): 
                    print('\t     Correct   \u2714')
                    print('\t','('+str(y+1)+')',listRevise[listOfList[randomNumberList]][listKey1[x]][y]) 
                    print('\n')
                    y=y+1
                    correct=correct+1
                else:    
                    print('\t     Incorrect    \u274c')
                    print('\t','('+str(y+1)+')',listRevise[listOfList[randomNumberList]][listKey1[x]][y])
                    print('\n') 
                    incorrect=incorrect+1
                   
            print("You have made "+str((incorrect/int(len(listRevise[listOfList[randomNumberList]][listKey1[x]])))*100)+" % mistake...")
            if((incorrect/len(listRevise[listOfList[randomNumberList]][listKey1[x]]))>=0.2):
                print ("\nRepeat Again because you make more than 20% mistake")
                x=x
            else:
                print ("\nMove to next topic because you make less mistake(below 20%)")
                x=x+1
            time.sleep(2)
            clear_output()   
    print('Total time to execute this part is ',datetime.now() - startTime)
            
if(number==4):
    clear_output()
    check=0
    for x in range(len(listRevise.keys())):
        randomNumberList=random.randint(0,len(listOfList)-1)
        listKey1=list(listRevise[listOfList[randomNumberList]].keys())
        x=0
        while(x<len(listRevise[listOfList[randomNumberList]].keys())):
            correct=0
            incorrect=0
            if(check==0):
                randomNumber=random.randint(0,len(listKey1)-1)
            print('Do you know this one ?   '+'\t'+'From '+str(listOfList[randomNumberList])+'\n'+'--> '+str(random.choice(listRevise[listOfList[randomNumberList]][listKey1[randomNumber]])))
            print('\n')
            topic=str(input("Enter Topic : "))
            print('\t  ',str(list(listRevise[listOfList[randomNumberList]].keys()).index(listKey1[randomNumber])+1)+'.' , listKey1[randomNumber],'('+str(len(listRevise[listOfList[randomNumberList]][listKey1[randomNumber]]))+')\n')
            y=0
            while(y<len(listRevise[listOfList[randomNumberList]][listKey1[randomNumber]])):
                word=str(input("Enter Name : "))
                if(wordMatch(word,listRevise[listOfList[randomNumberList]][listKey1[randomNumber]][y])): 
                    print('\t     Correct   \u2714')                    
                    print('\t','('+str(y+1)+')',listRevise[listOfList[randomNumberList]][listKey1[randomNumber]][y])
                    print('\n')
                    y=y+1
                    correct=correct+1
                else:    
                    print('\t     Incorrect    \u274c')
                    print('\t','('+str(y+1)+')',listRevise[listOfList[randomNumberList]][listKey1[randomNumber]][y])
                    print('\n') 
                    incorrect=incorrect+1   
            print("You have made "+str((incorrect/int(len(listRevise[listOfList[randomNumberList]][listKey1[randomNumber]])))*100)+" % mistake...")
            if((incorrect/len(listRevise[listOfList[randomNumberList]][listKey1[randomNumber]]))>=0.2):
                print ("\nRepeat Again because you make more than 20% mistake")
                x=x
                check=1
            else:
                print ("\nMove to next topic because you make less mistake(below 20%)")
                x=x+1
                del listKey1[randomNumber]
                check=0
            time.sleep(2)
            clear_output()
        del listOfList[randomNumberList]
    print('Total time to execute this part is ',datetime.now() - startTime)
        
if(number==5):
    clear_output()
    for x in range(len(listRevise.keys())):
        randomNumberList=x
        listKey1=list(listRevise[listOfList[randomNumberList]].keys())
        print('Total Group in ',listOfList[randomNumberList],' is ',len(listRevise[listOfList[randomNumberList]].keys()))
        time.sleep(len(listRevise[listOfList[randomNumberList]].keys()))
        #time.sleep(1)
        clear_output() 
        for x in range(0,len(listRevise[listOfList[randomNumberList]].keys())): 
            time.sleep(0.5)
            print("From ",listOfList[randomNumberList],'\t','Group Number :- ',listKey1.index(listKey1[x])+1,'\n')
            time.sleep(1.5)
            print("("+str(listKey1.index(listKey1[x])+1)+") "+str(listKey1[x])+" ("+str(len(listRevise[listOfList[randomNumberList]][listKey1[x]]))+")")
            time.sleep(5)
            print('\nNext.........')
            time.sleep(5)
            clear_output()   
            time.sleep(0.5) 
    print('Total time to execute this part is ',datetime.now() - startTime)
            
if(number==6):
    clear_output()    
    for x in range(len(listRevise.keys())):
        randomNumberList=x
        listKey1=list(listRevise[listOfList[randomNumberList]].keys())
        wordDict={value: x for x in listRevise[listOfList[randomNumberList]] for value in listRevise[listOfList[randomNumberList]][x]}
        listKey2=list(wordDict.keys())
        for x in range(len(listKey2)):
            time.sleep(0.25)
            randomNumber=random.randint(0,len(listKey2)-1)  
            print('Do you know this word ?\t','From ',listOfList[randomNumberList])            
            print('-->',listKey2[randomNumber])
            time.sleep(2)
            print('\n',wordDict[listKey2[randomNumber]])
            time.sleep(1.5)
            clear_output()
            time.sleep(0.25)
            del listKey2[randomNumber]
    print('Total time to execute this part is ',datetime.now() - startTime)
            
if(number==7):
    clear_output()
    for x in range(len(listRevise.keys())):
        randomNumberList=random.randint(0,len(listOfList)-1)
        listKey1=list(listRevise[listOfList[randomNumberList]].keys())
        print('Do you know this one ?   '+'\t'+'From '+str(listOfList[randomNumberList]),'\n')
        for x in range(len(listRevise[listOfList[randomNumberList]].keys())):
            randomNumber=random.randint(0,len(listKey1)-1)     
            print('--> '+str(random.choice(listRevise[listOfList[randomNumberList]][listKey1[randomNumber]])),'\n')            
            del listKey1[randomNumber]
        del listOfList[randomNumberList]
    print('Total time to execute this part is ',datetime.now() - startTime)
    
    
if(number==8):
    clear_output()
    print('Enter Words :\n')
    word=str(input()).lower()    
    for x in range(len(listRevise.keys())):
        listKey1=list(listRevise[listOfList[x]].keys())
        for y in range(len(listRevise[listOfList[x]].keys())):
            data=[c.split('(')[0].lower() for c in listRevise[listOfList[x]][listKey1[y]]]
            if(word in [c.split('(')[0].lower() for c in listRevise[listOfList[x]][listKey1[y]]]):
                print('\nGroup Name :('+str(list(listRevise[listOfList[x]].keys()).index(listKey1[y])+1)+')',listKey1[y])
                print('List Name  :',list(listRevise.keys())[x],'('+str(len(listRevise[listOfList[x]][listKey1[y]]))+')','\n')
                print(*listRevise[listOfList[x]][listKey1[y]], sep = "\n")
# Out:
# Enter Words :
#
# cow
